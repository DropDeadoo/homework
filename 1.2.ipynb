# %% [markdown]
# 1. Даны два целых числа. Выведите значение наименьшего из них

# %%
x = int(input())
y = int(input())
if x > y:
    print(y)
else:
    print(x)
# Out:
# 2
# 4
# 2

# %% [markdown]
# 2. Даны три целых числа. Выведите значение наименьшего из них

# %%
x = int(input())
y = int(input())
z = int(input())
if x > y and z > y:
    print(y)
if y > x and z > x:
    print(x)
if x > z and x > z:
    prin(z)
# Out:
# -5
# 7
# 33
# -5

# %% [markdown]
# 3. Шахматный слон ходит по диагонали. Даны 2-е различные клетки шахматной доски, определите, может ли слон попасть с первой клетки на вторую одним ходом.

# %%
x1 = int(input()) 
y1 = int(input())
x2 = int(input())
y2 = int (input())
if abs (y1-y2) == abs(x1-x2):
  print('yes')
else:
  print('no')
# Out:
# 1
# 2
# 3
# 4
# yes
