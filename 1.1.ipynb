# %% [markdown]
# 1. Вычислите 2 в 2019 степени

# %%
2**2019
# Out:
# ...

# %% [markdown]
# 2. Буква А, записана 121 раз

# %%
'A' * 121
# Out:
# 'AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA'

# %% [markdown]
# 3. Число 2019 запишите 40 раз и потом возвести во 2-ую степень
# #исправлено

# %%
x ='2019' * 40
x = int(x)**2
print(x)
# Out:
# 
